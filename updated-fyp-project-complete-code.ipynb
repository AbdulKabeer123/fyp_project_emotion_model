# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/fer2013/test/surprise/PublicTest_78686873.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_58522921.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_83796714.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_84428313.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_87978901.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_90978621.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_27580582.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_15760011.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_49739228.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_5351857.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_56096676.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_71692098.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_64532931.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_17886908.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_21410542.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_68745885.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_63291719.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_18505884.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_35732235.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_28247750.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_54508797.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_20065771.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_93901885.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_40404994.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_77901708.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_43252384.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_6512456.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_22313021.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_26572350.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_30329445.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_64680038.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_96986087.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_18109329.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_81281432.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_66164599.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_15712657.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_4690717.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_42347603.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_18808914.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_83674814.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_15433995.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_88902041.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_11501834.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_73221398.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_27916929.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_55075980.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_34869248.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_13590284.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_17512663.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_14015382.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_83231837.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_30819571.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_88540078.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_71265996.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_28499099.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_18135788.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_40559227.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_64218614.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_97342741.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_62398284.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_65996903.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_49102178.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_47534258.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_27366015.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_91946755.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_61993656.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_45226282.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_48967459.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_48415985.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_6862393.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_78248169.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_58192505.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_45942873.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_89002309.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_67127914.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_11102676.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_44603096.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_66702303.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_39436840.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_71175068.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_99005688.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_69939146.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_60718510.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_74775203.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_71094703.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_10072988.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_39146457.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_27752387.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_71485256.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_10780425.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_67014114.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_54842414.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_24011006.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_27407773.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_42872438.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_99502303.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_35609852.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_37073420.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_40967103.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_75549401.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_78295416.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_61881861.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_91276966.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_25532192.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_66101683.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_139065.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_48185502.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_62222978.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_12795179.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_89906957.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_61453734.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_38343743.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_1673508.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_40148704.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_73073050.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_33008622.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_20677546.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_16764169.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_97429032.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_93686328.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_88046230.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_34869242.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_2264189.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_81426356.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_9068096.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_50429957.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_10712253.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_72026283.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_57523082.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_81489797.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_63826397.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_84762716.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_25053327.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_43820728.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_57570036.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_73154398.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_70455077.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_69615782.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_41853394.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_81424820.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_20248242.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_37360205.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_53655471.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_37239771.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_24560345.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_35132840.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_18884751.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_17911043.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_54022427.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_84891285.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_26047658.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_34206950.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_37426588.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_22194410.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_742095.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_95250872.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_12400594.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_77507848.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_49089142.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_60993930.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_47843431.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_51597356.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_53992987.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_15585729.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_28272710.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_61779535.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_12641070.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_91117138.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_78536175.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_25765328.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_51072428.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_91187876.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_72207843.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_42473844.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_21140607.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_73985173.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_20530760.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_94417003.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_51011425.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_99242645.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_91780905.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_85704124.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_63477934.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_77130003.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_67079560.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_23652329.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_25288007.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_44531124.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_78581325.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_40528928.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_13683211.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_63467129.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_34124532.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_44742499.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_66131494.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_17155920.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_90847876.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_4639501.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_99454564.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_4773003.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_13980595.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_38836037.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_642696.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_47060827.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_57431452.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_36377429.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_67565857.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_76235773.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_38247925.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_12186725.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_29569925.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_25300564.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_2529039.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_75752209.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_97190139.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_45072574.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_7431524.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_47864767.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_47859715.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_66000374.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_71771739.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_49077480.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_35290127.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_41439516.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_18486097.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_17677007.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_29203341.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_34645495.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_39513657.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_23514058.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_37638961.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_13719697.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_34706936.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_80382718.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_22576434.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_85402036.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_15665048.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_24449829.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_20800943.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_56650171.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_36718809.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_43690380.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_97733555.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_41696704.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_1338609.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_71124930.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_68102403.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_84091760.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_94398836.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_17928476.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_15746138.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_40189715.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_95404064.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_39767990.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_60031524.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_15205762.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_92553807.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_3534072.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_50683363.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_66012598.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_53292967.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_4493968.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_5943934.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_64107181.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_66905202.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_59195628.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_14204552.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_40584155.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_30987122.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_80352203.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_48402123.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_64052461.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_82970188.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_60102040.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_57882068.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_56072208.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_55404404.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_52491850.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_67290585.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_62544233.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_7808000.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_51939334.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_4915092.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_1076980.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_91967730.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_63069551.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_66332069.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_66326152.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_81424886.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_39678108.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_58123153.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_11056779.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_3854174.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_5539787.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_43656605.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_71616306.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_15635080.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_69627128.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_54101876.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_76524639.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_31470914.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_34334611.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_6010264.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_8416578.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_38755783.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_71748648.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_38809207.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_40354251.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_42928793.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_75638667.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_89880334.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_62122732.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_10427382.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_24065334.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_66065964.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_72725289.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_28328252.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_75474602.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_98972870.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_74706022.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_73205039.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_61619813.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_48789919.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_94585791.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_66788337.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_54005456.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_97995446.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_38966726.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_59852729.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_78713133.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_29450477.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_46331172.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_26068292.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_89814190.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_74961438.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_54301394.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_98567249.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_84658197.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_76349096.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_60383922.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_20980168.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_78087783.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_8153825.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_55324865.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_10089743.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_81832781.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_31798685.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_96673755.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_34422385.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_52307515.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_53165058.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_58283362.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_52359086.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_25512952.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_96283626.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_64423807.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_25086092.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_16568907.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_47189201.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_11365666.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_86810004.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_78809741.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_51366800.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_57199212.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_10782186.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_17681379.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_3560560.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_34166920.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_31004145.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_65209346.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_34990545.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_87304390.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_53795000.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_66095589.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_56618052.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_15523257.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_12065785.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_32006399.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_46663858.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_2034433.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_61597434.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_22986053.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_84888763.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_1388103.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_89914960.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_6116699.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_5167971.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_31378427.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_4156626.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_41737997.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_13861015.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_13194846.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_76841432.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_14290563.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_76422616.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_83997303.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_75437950.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_65640293.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_1667417.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_62963706.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_48988865.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_43801413.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_66424456.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_49993315.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_93462303.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_19541998.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_84961143.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_30726237.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_78614220.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_20993679.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_2349643.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_79872412.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_75062.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_2615422.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_97780010.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_53530460.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_36465312.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_7569276.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_94044652.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_50616965.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_94819790.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_91929864.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_23654848.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_40295337.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_94809551.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_78017321.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_14561216.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_5528245.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_18285200.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_21541129.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_59347947.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_95585614.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_81098275.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_6806257.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_19276218.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_14802111.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_81021004.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_78415202.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_8875376.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_30899836.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_78591767.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_4819015.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_24716133.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_64657369.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_2697877.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_87959338.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_4072500.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_47471236.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_77128723.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_61057825.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_13722582.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_97163676.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_79983459.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_73853005.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_70595908.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_67417043.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_53006385.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_79676384.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_62895105.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_7556977.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_11715606.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_30031654.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_62145473.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_94624784.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_23371947.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_86877135.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_49049109.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_76871463.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_84568132.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_92016036.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_23216863.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_9610220.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_61359508.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_20531357.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_14592510.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_44774809.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_63105509.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_83487267.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_10709121.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_63379834.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_17248098.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_34696648.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_21661848.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_82041388.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_78180569.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_94263273.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_2283840.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_57200649.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_96829183.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_10984020.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_63760007.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_59751984.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_52473093.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_62072018.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_72371044.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_35458201.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_28786878.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_28459548.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_95365921.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_48991844.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_14015146.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_6587334.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_70796806.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_77729498.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_21197746.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_72365149.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_5954279.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_67376319.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_3206770.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_4506807.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_83710885.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_43692311.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_58944156.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_44720580.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_94285787.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_98556225.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_3185131.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_64479147.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_60435558.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_59595884.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_16678610.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_34419863.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_28041929.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_82391300.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_96143637.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_93480805.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_45297572.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_5899302.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_9171383.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_68447996.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_29531738.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_53078668.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_73584259.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_81533064.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_23048354.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_16757278.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_104142.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_28665216.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_18350292.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_60460044.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_63218849.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_45784436.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_76249877.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_97564373.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_45239840.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_82718333.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_34933787.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_70605143.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_47372428.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_5010883.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_6719287.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_58393533.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_77715773.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_35266346.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_97558106.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_45976722.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_19373509.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_73588122.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_82049883.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_35686529.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_98453427.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_30073403.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_62174534.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_67579465.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_59029114.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_23824214.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_69492660.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_77634297.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_27272456.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_94628526.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_98873206.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_22781960.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_99719047.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_50922918.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_87012441.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_44526433.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_35396845.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_44179455.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_358786.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_3012169.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_18865959.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_36800464.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_1709990.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_38805770.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_32600033.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_84156685.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_68423633.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_85056155.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_5897498.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_7850751.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_24578078.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_22228657.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_77274972.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_46372964.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_66691033.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_46290479.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_17512816.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_68799766.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_48874576.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_21575786.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_23695727.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_98089595.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_37963456.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_35838312.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_33947662.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_31186047.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_66966629.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_23583223.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_31247292.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_15770032.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_71740233.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_13980590.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_34688181.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_25336581.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_66300077.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_53542593.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_15739977.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_31171869.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_60064036.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_8587491.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_46144482.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_51555877.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_78751461.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_97536839.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_51257619.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_7531182.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_80135522.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_99709238.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_85263892.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_44907068.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_66116810.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_15630467.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_69457341.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_48628749.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_71260578.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_48016910.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_81923456.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_69316109.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_85107326.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_74762386.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_53048981.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_26378686.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_95778572.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_72989993.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_85943952.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_45066375.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_62778623.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_91476603.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_17167274.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_51861198.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_18422068.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_64740817.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_44757434.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_34028245.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_92591165.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_11531030.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_13992260.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_53302575.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_63231524.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_46006432.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_67564456.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_59661554.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_34755910.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_37692447.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_66742943.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_19681601.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_92484279.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_11445412.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_88565861.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_41450476.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_92242142.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_66344275.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_42463795.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_59707648.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_914251.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_24738517.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_35042409.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_67327289.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_18712944.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_19807053.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_17526434.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_32430628.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_78283991.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_46713098.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_1623206.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_21253405.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_34601276.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_55637158.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_40207266.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_2017514.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_79429682.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_14561798.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_52633253.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_42746467.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_60337169.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_47639345.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_17479537.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_15230404.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_8610610.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_46929671.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_90653008.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_34128620.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_47899862.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_45821911.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_47965694.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_60450589.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_88079148.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_46434045.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_50614182.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_42864737.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_17194400.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_84844703.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_98946299.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_80572685.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_50884349.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_32045.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_12516829.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_29832450.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_78561701.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_96333750.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_64629991.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_17047937.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_50994876.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_36386071.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_10754294.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_94828377.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_11664182.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_13291266.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_28516575.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_65722213.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_99446963.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_67692023.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_58891167.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_51540875.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_22866077.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_10775220.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_70240609.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_23987357.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_4616983.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_36889392.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_34468339.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_73869541.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_93419159.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_5605924.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_28198711.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_77783263.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_20242544.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_53324760.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_42838603.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_77409138.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_3628332.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_49826465.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_68250414.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_97902387.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_80135557.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_75723378.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_83217196.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_96538817.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_70904962.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_71444767.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_16022588.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_43207789.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_54464589.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_51290776.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_82282745.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_25271151.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_83394959.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_91265725.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_17898849.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_26280063.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_87631890.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_29260214.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_90663142.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_64474053.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_5114163.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_93768797.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_39373170.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_97271462.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_72822627.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_58564335.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_51456832.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_25064886.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_86687578.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_55106444.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_20732965.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_17484027.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_57162802.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_69922592.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_84535961.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_77993783.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_79494187.jpg
# /kaggle/input/fer2013/test/surprise/PrivateTest_22237388.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_60948590.jpg
# /kaggle/input/fer2013/test/surprise/PublicTest_32575449.jpg
# ...
# /kaggle/input/fer2013/train/happy/Training_25207387.jpg
# /kaggle/input/fer2013/train/happy/Training_86684937.jpg
# /kaggle/input/fer2013/train/happy/Training_69525234.jpg
# /kaggle/input/fer2013/train/happy/Training_5604708.jpg
# /kaggle/input/fer2013/train/happy/Training_97564634.jpg
# /kaggle/input/fer2013/train/happy/Training_26628710.jpg
# /kaggle/input/fer2013/train/happy/Training_47915502.jpg
# /kaggle/input/fer2013/train/happy/Training_30536062.jpg
# /kaggle/input/fer2013/train/happy/Training_85243344.jpg
# /kaggle/input/fer2013/train/happy/Training_18470186.jpg
# /kaggle/input/fer2013/train/happy/Training_36964629.jpg
# /kaggle/input/fer2013/train/happy/Training_82172580.jpg
# /kaggle/input/fer2013/train/happy/Training_92525700.jpg
# /kaggle/input/fer2013/train/happy/Training_16044134.jpg
# /kaggle/input/fer2013/train/happy/Training_61017672.jpg
# /kaggle/input/fer2013/train/happy/Training_46933826.jpg
# /kaggle/input/fer2013/train/happy/Training_5243164.jpg
# /kaggle/input/fer2013/train/happy/Training_68479926.jpg
# /kaggle/input/fer2013/train/happy/Training_28086809.jpg
# /kaggle/input/fer2013/train/happy/Training_93402651.jpg
# /kaggle/input/fer2013/train/happy/Training_90567888.jpg
# /kaggle/input/fer2013/train/happy/Training_55632462.jpg
# /kaggle/input/fer2013/train/happy/Training_80442294.jpg
# /kaggle/input/fer2013/train/happy/Training_72823651.jpg
# /kaggle/input/fer2013/train/happy/Training_46416822.jpg
# /kaggle/input/fer2013/train/happy/Training_16338930.jpg
# /kaggle/input/fer2013/train/happy/Training_51998242.jpg
# /kaggle/input/fer2013/train/happy/Training_29391894.jpg
# /kaggle/input/fer2013/train/happy/Training_39639717.jpg
# /kaggle/input/fer2013/train/happy/Training_23380215.jpg
# /kaggle/input/fer2013/train/happy/Training_7651749.jpg
# /kaggle/input/fer2013/train/happy/Training_58722594.jpg
# /kaggle/input/fer2013/train/happy/Training_52709986.jpg
# /kaggle/input/fer2013/train/happy/Training_39000218.jpg
# /kaggle/input/fer2013/train/happy/Training_48243367.jpg
# /kaggle/input/fer2013/train/happy/Training_87828970.jpg
# /kaggle/input/fer2013/train/happy/Training_5073014.jpg
# /kaggle/input/fer2013/train/happy/Training_37591022.jpg
# /kaggle/input/fer2013/train/happy/Training_14866954.jpg
# /kaggle/input/fer2013/train/happy/Training_38016578.jpg
# /kaggle/input/fer2013/train/happy/Training_69857378.jpg
# /kaggle/input/fer2013/train/happy/Training_82825139.jpg
# /kaggle/input/fer2013/train/happy/Training_80274847.jpg
# /kaggle/input/fer2013/train/happy/Training_46473303.jpg
# /kaggle/input/fer2013/train/happy/Training_19694742.jpg
# /kaggle/input/fer2013/train/happy/Training_29646945.jpg
# /kaggle/input/fer2013/train/happy/Training_25381151.jpg
# /kaggle/input/fer2013/train/happy/Training_7845176.jpg
# /kaggle/input/fer2013/train/happy/Training_46171710.jpg
# /kaggle/input/fer2013/train/happy/Training_38502360.jpg
# /kaggle/input/fer2013/train/happy/Training_80424540.jpg
# /kaggle/input/fer2013/train/happy/Training_80181320.jpg
# /kaggle/input/fer2013/train/happy/Training_55415338.jpg
# /kaggle/input/fer2013/train/happy/Training_73639399.jpg
# /kaggle/input/fer2013/train/happy/Training_32711027.jpg
# /kaggle/input/fer2013/train/happy/Training_23109615.jpg
# /kaggle/input/fer2013/train/happy/Training_10181727.jpg
# /kaggle/input/fer2013/train/happy/Training_26147430.jpg
# /kaggle/input/fer2013/train/happy/Training_32817045.jpg
# /kaggle/input/fer2013/train/happy/Training_61732480.jpg
# /kaggle/input/fer2013/train/happy/Training_51022786.jpg
# /kaggle/input/fer2013/train/happy/Training_22033863.jpg
# /kaggle/input/fer2013/train/happy/Training_55486054.jpg
# /kaggle/input/fer2013/train/happy/Training_65529091.jpg
# /kaggle/input/fer2013/train/happy/Training_61263386.jpg
# /kaggle/input/fer2013/train/happy/Training_11869640.jpg
# /kaggle/input/fer2013/train/happy/Training_86017612.jpg
# /kaggle/input/fer2013/train/happy/Training_33726083.jpg
# /kaggle/input/fer2013/train/happy/Training_1389208.jpg
# /kaggle/input/fer2013/train/happy/Training_63504886.jpg
# /kaggle/input/fer2013/train/happy/Training_8651008.jpg
# /kaggle/input/fer2013/train/happy/Training_29976217.jpg
# /kaggle/input/fer2013/train/happy/Training_93197270.jpg
# /kaggle/input/fer2013/train/happy/Training_11767080.jpg
# /kaggle/input/fer2013/train/happy/Training_98680743.jpg
# /kaggle/input/fer2013/train/happy/Training_467541.jpg
# /kaggle/input/fer2013/train/happy/Training_95463557.jpg
# /kaggle/input/fer2013/train/happy/Training_4973742.jpg
# /kaggle/input/fer2013/train/happy/Training_43228222.jpg
# /kaggle/input/fer2013/train/happy/Training_25590197.jpg
# /kaggle/input/fer2013/train/happy/Training_8807884.jpg
# /kaggle/input/fer2013/train/happy/Training_13514662.jpg
# /kaggle/input/fer2013/train/happy/Training_2461122.jpg
# /kaggle/input/fer2013/train/happy/Training_10465648.jpg
# /kaggle/input/fer2013/train/happy/Training_81669901.jpg
# /kaggle/input/fer2013/train/happy/Training_53882784.jpg
# /kaggle/input/fer2013/train/happy/Training_4426524.jpg
# /kaggle/input/fer2013/train/happy/Training_35573536.jpg
# /kaggle/input/fer2013/train/happy/Training_63363759.jpg
# /kaggle/input/fer2013/train/happy/Training_94928306.jpg
# /kaggle/input/fer2013/train/happy/Training_77873804.jpg
# /kaggle/input/fer2013/train/happy/Training_72939358.jpg
# /kaggle/input/fer2013/train/happy/Training_93001555.jpg
# /kaggle/input/fer2013/train/happy/Training_79854658.jpg
# /kaggle/input/fer2013/train/happy/Training_17295144.jpg
# /kaggle/input/fer2013/train/happy/Training_6152251.jpg
# /kaggle/input/fer2013/train/happy/Training_15781430.jpg
# /kaggle/input/fer2013/train/happy/Training_41167122.jpg
# /kaggle/input/fer2013/train/happy/Training_93777637.jpg
# /kaggle/input/fer2013/train/happy/Training_20953176.jpg
# /kaggle/input/fer2013/train/happy/Training_41050792.jpg
# /kaggle/input/fer2013/train/happy/Training_28780850.jpg
# /kaggle/input/fer2013/train/happy/Training_41687551.jpg
# /kaggle/input/fer2013/train/happy/Training_96284120.jpg
# /kaggle/input/fer2013/train/happy/Training_9972549.jpg
# /kaggle/input/fer2013/train/happy/Training_26049115.jpg
# /kaggle/input/fer2013/train/happy/Training_41821373.jpg
# /kaggle/input/fer2013/train/happy/Training_16048380.jpg
# /kaggle/input/fer2013/train/happy/Training_34930888.jpg
# /kaggle/input/fer2013/train/happy/Training_92858175.jpg
# /kaggle/input/fer2013/train/happy/Training_84562948.jpg
# /kaggle/input/fer2013/train/happy/Training_43903422.jpg
# /kaggle/input/fer2013/train/happy/Training_95131286.jpg
# /kaggle/input/fer2013/train/happy/Training_25184507.jpg
# /kaggle/input/fer2013/train/happy/Training_58733906.jpg
# /kaggle/input/fer2013/train/happy/Training_52542210.jpg
# /kaggle/input/fer2013/train/happy/Training_98014225.jpg
# /kaggle/input/fer2013/train/happy/Training_35132368.jpg
# /kaggle/input/fer2013/train/happy/Training_16439120.jpg
# /kaggle/input/fer2013/train/happy/Training_22747348.jpg
# /kaggle/input/fer2013/train/happy/Training_50536505.jpg
# /kaggle/input/fer2013/train/happy/Training_536466.jpg
# /kaggle/input/fer2013/train/happy/Training_35858702.jpg
# /kaggle/input/fer2013/train/happy/Training_55070751.jpg
# /kaggle/input/fer2013/train/happy/Training_14713978.jpg
# /kaggle/input/fer2013/train/happy/Training_24494905.jpg
# /kaggle/input/fer2013/train/happy/Training_74568103.jpg
# /kaggle/input/fer2013/train/happy/Training_81116476.jpg
# /kaggle/input/fer2013/train/happy/Training_24392125.jpg
# /kaggle/input/fer2013/train/happy/Training_18285567.jpg
# /kaggle/input/fer2013/train/happy/Training_89266229.jpg
# /kaggle/input/fer2013/train/happy/Training_47490067.jpg
# /kaggle/input/fer2013/train/happy/Training_10437958.jpg
# /kaggle/input/fer2013/train/happy/Training_82869157.jpg
# /kaggle/input/fer2013/train/happy/Training_72953244.jpg
# /kaggle/input/fer2013/train/happy/Training_80333809.jpg
# /kaggle/input/fer2013/train/happy/Training_75293350.jpg
# /kaggle/input/fer2013/train/happy/Training_63185067.jpg
# /kaggle/input/fer2013/train/happy/Training_3439464.jpg
# /kaggle/input/fer2013/train/happy/Training_44869747.jpg
# /kaggle/input/fer2013/train/happy/Training_36685001.jpg
# /kaggle/input/fer2013/train/happy/Training_93206918.jpg
# /kaggle/input/fer2013/train/happy/Training_18880201.jpg
# /kaggle/input/fer2013/train/happy/Training_36519995.jpg
# /kaggle/input/fer2013/train/happy/Training_70514959.jpg
# /kaggle/input/fer2013/train/happy/Training_3416891.jpg
# /kaggle/input/fer2013/train/happy/Training_65946872.jpg
# /kaggle/input/fer2013/train/happy/Training_66564239.jpg
# /kaggle/input/fer2013/train/happy/Training_63537225.jpg
# /kaggle/input/fer2013/train/happy/Training_49883752.jpg
# /kaggle/input/fer2013/train/happy/Training_77118913.jpg
# /kaggle/input/fer2013/train/happy/Training_42700566.jpg
# /kaggle/input/fer2013/train/happy/Training_87786807.jpg
# /kaggle/input/fer2013/train/happy/Training_4137746.jpg
# /kaggle/input/fer2013/train/happy/Training_88198452.jpg
# /kaggle/input/fer2013/train/happy/Training_80006048.jpg
# /kaggle/input/fer2013/train/happy/Training_98645975.jpg
# /kaggle/input/fer2013/train/happy/Training_16579675.jpg
# /kaggle/input/fer2013/train/happy/Training_86088144.jpg
# /kaggle/input/fer2013/train/happy/Training_50000796.jpg
# /kaggle/input/fer2013/train/happy/Training_96665698.jpg
# /kaggle/input/fer2013/train/happy/Training_90996119.jpg
# /kaggle/input/fer2013/train/happy/Training_47925105.jpg
# /kaggle/input/fer2013/train/happy/Training_32721236.jpg
# /kaggle/input/fer2013/train/happy/Training_75003349.jpg
# /kaggle/input/fer2013/train/happy/Training_45759803.jpg
# /kaggle/input/fer2013/train/happy/Training_43781228.jpg
# /kaggle/input/fer2013/train/happy/Training_12076274.jpg
# /kaggle/input/fer2013/train/happy/Training_93571817.jpg
# /kaggle/input/fer2013/train/happy/Training_76798321.jpg
# /kaggle/input/fer2013/train/happy/Training_69287926.jpg
# /kaggle/input/fer2013/train/happy/Training_76746311.jpg
# /kaggle/input/fer2013/train/happy/Training_30215903.jpg
# /kaggle/input/fer2013/train/happy/Training_4632503.jpg
# /kaggle/input/fer2013/train/happy/Training_12911440.jpg
# /kaggle/input/fer2013/train/happy/Training_59043651.jpg
# /kaggle/input/fer2013/train/happy/Training_29017837.jpg
# /kaggle/input/fer2013/train/happy/Training_32452414.jpg
# /kaggle/input/fer2013/train/happy/Training_66966880.jpg
# /kaggle/input/fer2013/train/happy/Training_74105191.jpg
# /kaggle/input/fer2013/train/happy/Training_73660597.jpg
# /kaggle/input/fer2013/train/happy/Training_11084967.jpg
# /kaggle/input/fer2013/train/happy/Training_59556478.jpg
# /kaggle/input/fer2013/train/happy/Training_11500165.jpg
# /kaggle/input/fer2013/train/happy/Training_97118844.jpg
# /kaggle/input/fer2013/train/happy/Training_92140607.jpg
# /kaggle/input/fer2013/train/happy/Training_23208972.jpg
# /kaggle/input/fer2013/train/happy/Training_73600586.jpg
# /kaggle/input/fer2013/train/happy/Training_1161132.jpg
# /kaggle/input/fer2013/train/happy/Training_40338984.jpg
# /kaggle/input/fer2013/train/happy/Training_89460378.jpg
# /kaggle/input/fer2013/train/happy/Training_89467210.jpg
# /kaggle/input/fer2013/train/happy/Training_44314963.jpg
# /kaggle/input/fer2013/train/happy/Training_11826511.jpg
# /kaggle/input/fer2013/train/happy/Training_18383577.jpg
# /kaggle/input/fer2013/train/happy/Training_23585523.jpg
# /kaggle/input/fer2013/train/happy/Training_42563622.jpg
# /kaggle/input/fer2013/train/happy/Training_67733378.jpg
# /kaggle/input/fer2013/train/happy/Training_29706177.jpg
# /kaggle/input/fer2013/train/happy/Training_68128508.jpg
# /kaggle/input/fer2013/train/happy/Training_84171861.jpg
# /kaggle/input/fer2013/train/happy/Training_2300493.jpg
# /kaggle/input/fer2013/train/happy/Training_52284317.jpg
# /kaggle/input/fer2013/train/happy/Training_4575219.jpg
# /kaggle/input/fer2013/train/happy/Training_40600052.jpg
# /kaggle/input/fer2013/train/happy/Training_51369743.jpg
# /kaggle/input/fer2013/train/happy/Training_77465577.jpg
# /kaggle/input/fer2013/train/happy/Training_23341828.jpg
# /kaggle/input/fer2013/train/happy/Training_74637851.jpg
# /kaggle/input/fer2013/train/happy/Training_46583470.jpg
# /kaggle/input/fer2013/train/happy/Training_17389267.jpg
# /kaggle/input/fer2013/train/happy/Training_61374496.jpg
# /kaggle/input/fer2013/train/happy/Training_67626163.jpg
# /kaggle/input/fer2013/train/happy/Training_65644663.jpg
# /kaggle/input/fer2013/train/happy/Training_89106192.jpg
# /kaggle/input/fer2013/train/happy/Training_27040444.jpg
# /kaggle/input/fer2013/train/happy/Training_3887027.jpg
# /kaggle/input/fer2013/train/happy/Training_62776483.jpg
# /kaggle/input/fer2013/train/happy/Training_25815302.jpg
# /kaggle/input/fer2013/train/happy/Training_62675357.jpg
# /kaggle/input/fer2013/train/happy/Training_9827621.jpg
# /kaggle/input/fer2013/train/happy/Training_79769038.jpg
# /kaggle/input/fer2013/train/happy/Training_45426284.jpg
# /kaggle/input/fer2013/train/happy/Training_74771618.jpg
# /kaggle/input/fer2013/train/happy/Training_27690434.jpg
# /kaggle/input/fer2013/train/happy/Training_73793523.jpg
# /kaggle/input/fer2013/train/happy/Training_11542190.jpg
# /kaggle/input/fer2013/train/happy/Training_91511544.jpg
# /kaggle/input/fer2013/train/happy/Training_68402814.jpg
# /kaggle/input/fer2013/train/happy/Training_87749725.jpg
# /kaggle/input/fer2013/train/happy/Training_72094823.jpg
# /kaggle/input/fer2013/train/happy/Training_46218047.jpg
# /kaggle/input/fer2013/train/happy/Training_63388208.jpg
# /kaggle/input/fer2013/train/happy/Training_66392847.jpg
# /kaggle/input/fer2013/train/happy/Training_91799987.jpg
# /kaggle/input/fer2013/train/happy/Training_56541394.jpg
# /kaggle/input/fer2013/train/happy/Training_62256585.jpg
# /kaggle/input/fer2013/train/happy/Training_79234386.jpg
# /kaggle/input/fer2013/train/happy/Training_11514199.jpg
# /kaggle/input/fer2013/train/happy/Training_91143472.jpg
# /kaggle/input/fer2013/train/happy/Training_91322946.jpg
# /kaggle/input/fer2013/train/happy/Training_50227747.jpg
# /kaggle/input/fer2013/train/happy/Training_80200675.jpg
# /kaggle/input/fer2013/train/happy/Training_60659475.jpg
# /kaggle/input/fer2013/train/happy/Training_1918710.jpg
# /kaggle/input/fer2013/train/happy/Training_77408087.jpg
# /kaggle/input/fer2013/train/happy/Training_27407179.jpg
# /kaggle/input/fer2013/train/happy/Training_58703350.jpg
# /kaggle/input/fer2013/train/happy/Training_82657908.jpg
# /kaggle/input/fer2013/train/happy/Training_86243115.jpg
# /kaggle/input/fer2013/train/happy/Training_60254430.jpg
# /kaggle/input/fer2013/train/happy/Training_85323258.jpg
# /kaggle/input/fer2013/train/happy/Training_177442.jpg
# /kaggle/input/fer2013/train/happy/Training_91304881.jpg
# /kaggle/input/fer2013/train/happy/Training_88932198.jpg
# /kaggle/input/fer2013/train/happy/Training_20327769.jpg
# /kaggle/input/fer2013/train/happy/Training_6862832.jpg
# /kaggle/input/fer2013/train/happy/Training_57521268.jpg
# /kaggle/input/fer2013/train/happy/Training_7287745.jpg
# /kaggle/input/fer2013/train/happy/Training_9171710.jpg
# /kaggle/input/fer2013/train/happy/Training_6138212.jpg
# /kaggle/input/fer2013/train/happy/Training_95550959.jpg
# /kaggle/input/fer2013/train/happy/Training_61866423.jpg
# /kaggle/input/fer2013/train/happy/Training_43344839.jpg
# /kaggle/input/fer2013/train/happy/Training_65728119.jpg
# /kaggle/input/fer2013/train/happy/Training_19128080.jpg
# /kaggle/input/fer2013/train/happy/Training_44045488.jpg
# /kaggle/input/fer2013/train/happy/Training_33878226.jpg
# /kaggle/input/fer2013/train/happy/Training_54675927.jpg
# /kaggle/input/fer2013/train/happy/Training_6515366.jpg
# /kaggle/input/fer2013/train/happy/Training_73322651.jpg
# /kaggle/input/fer2013/train/happy/Training_46918975.jpg
# /kaggle/input/fer2013/train/happy/Training_46789907.jpg
# /kaggle/input/fer2013/train/happy/Training_29050965.jpg
# /kaggle/input/fer2013/train/happy/Training_15952123.jpg
# /kaggle/input/fer2013/train/happy/Training_96272562.jpg
# /kaggle/input/fer2013/train/happy/Training_16109497.jpg
# /kaggle/input/fer2013/train/happy/Training_59802408.jpg
# /kaggle/input/fer2013/train/happy/Training_23983839.jpg
# /kaggle/input/fer2013/train/happy/Training_61893124.jpg
# /kaggle/input/fer2013/train/happy/Training_87865303.jpg
# /kaggle/input/fer2013/train/happy/Training_18866880.jpg
# /kaggle/input/fer2013/train/happy/Training_16513509.jpg
# /kaggle/input/fer2013/train/happy/Training_10834907.jpg
# /kaggle/input/fer2013/train/happy/Training_30459679.jpg
# /kaggle/input/fer2013/train/happy/Training_95673040.jpg

# %%
import os
import keras
import itertools
import numpy as np
import pandas as pd
import seaborn as sn
from collections import Counter
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Flatten, Dropout,BatchNormalization ,Activation, GlobalAveragePooling2D
from tensorflow.keras.layers import GaussianNoise
from tensorflow.keras import regularizers

import keras.backend as K
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.callbacks import ReduceLROnPlateau,ModelCheckpoint,EarlyStopping

from IPython.display import Image, HTML
from tensorflow.keras.utils import plot_model

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Declare path
train_dir = '../input/fer2013/train/'
test_dir = '../input/fer2013/test/'

# Image size
IMAGE_SIZE = (48,48)
IMAGE_SHAPE = IMAGE_SIZE + (3,)

BS = 64
EPOCHS = 100
ADAM_LEARNING_RATE = 0.0001
PATIENCE = 10

classes = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

# Function to count images per expression
def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = os.path.join(path, expression)
        if os.path.isdir(dir_):
            dict_[expression.capitalize()] = len(os.listdir(dir_))  # Capitalizing labels
    df = pd.DataFrame(dict_, index=[set_])
    return df

train_count = count_exp(train_dir, 'train')
test_count = count_exp(test_dir, 'test')

print(train_count)
print(test_count)
# Out:
#        Surprise  Fear  Angry  Neutral   Sad  Disgust  Happy
# train      3171  4097   3995     4965  4830      436   7215
#       Surprise  Fear  Angry  Neutral   Sad  Disgust  Happy
# test       831  1024    958     1233  1247      111   1774

# %%
# Plot the graph with corrected labels
train_count.transpose().plot(kind='bar', legend=False)
plt.title("Emotion Distribution in Training Data")
plt.xlabel("Emotions")
plt.ylabel("Number of Images")
plt.xticks(rotation=45)
plt.show()

# %%
test_count.transpose().plot(kind='bar')
# Out:
# <Axes: >

# %%
# Data augmentation

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   featurewise_center=False,
                                   featurewise_std_normalization=False,
                                   rotation_range=10,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   zoom_range=0.1,
                                   horizontal_flip=True)

test_datagen  = ImageDataGenerator(rescale = 1./255)

# %%
# Load datasat

train_dataset  = train_datagen.flow_from_directory(directory = train_dir,
                                                   target_size = IMAGE_SIZE,
                                                   class_mode = 'categorical',
                                                   batch_size = BS)

test_dataset = test_datagen.flow_from_directory(directory = test_dir,
                                                  target_size = IMAGE_SIZE,
                                                  class_mode = 'categorical',
                                                  shuffle =True,
                                                  batch_size = BS)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
# Data labels

class_labels = test_dataset.class_indices
class_labels
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
# Function to count the number of images in each class (expression)
def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = os.path.join(path, expression)  # Ensure path is correct
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df

train_count = count_exp(train_dir, 'train')
test_count = count_exp(test_dir, 'test')

# Concatenate the DataFrames using pd.concat() instead of append()
combined_count = pd.concat([train_count, test_count])

# Display the result as HTML
HTML(combined_count.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>surprise</th>
#       <th>fear</th>
#       <th>angry</th>
#       <th>neutral</th>
#       <th>sad</th>
#       <th>disgust</th>
#       <th>happy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>3171</td>
#       <td>4097</td>
#       <td>3995</td>
#       <td>4965</td>
#       <td>4830</td>
#       <td>436</td>
#       <td>7215</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>831</td>
#       <td>1024</td>
#       <td>958</td>
#       <td>1233</td>
#       <td>1247</td>
#       <td>111</td>
#       <td>1774</td>
#     </tr>
#   </tbody>
# </table>

# %%
# See the shape of any data

train_sample=next(train_dataset)
print(train_sample[0].shape)
# Out:
# (64, 48, 48, 3)

# %%
# Extract class names and counts
x = [emotion.capitalize() for emotion in test_count.columns]  # Ensure all labels are capitalized
y1 = train_count.iloc[0].to_list()
y2 = test_count.iloc[0].to_list()

# Plot updated graph
plt.figure(figsize=(12,7))
plt.bar(x, y1, color='blue', label="Train")
plt.bar(x, y2, bottom=y1, color='violet', label="Test")

plt.xlabel("Emotions")
plt.ylabel("Train & Test Data")
plt.title("FER-2013 Dataset Distribution")
plt.xticks(rotation=45)  # Rotate for better visibility
plt.legend(loc='upper left')

# Save and show plot
plt.savefig('distribution.png')
plt.show()

# %%
# Plot image of each class

plt.figure(figsize=(14,22))
i = 1
for expression in os.listdir(train_dir):
    img = load_img((train_dir + expression +'/'+ os.listdir(train_dir + expression)[1]))
    plt.subplot(1,7,i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %%
# VGG16

base_model = tf.keras.applications.VGG16(input_shape= IMAGE_SHAPE,include_top=False,weights="imagenet")
base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 48, 48, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 48, 48, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 48, 48, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 24, 24, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 24, 24, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 12, 12, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 12, 12, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 12, 12, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 12, 12, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 6, 6, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 6, 6, 512)           │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 6, 6, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 6, 6, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 3, 3, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 3, 3, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 3, 3, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 3, 3, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 1, 1, 512)           │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Freezing Layers

for layer in base_model.layers[:11]:
    layer.trainable=False

# %%
# Define your model (make sure it's run first)
model = Sequential()
# Add layers to the model
# Example layers
model.add(Dense(64, activation='relu', input_shape=(784,)))
model.add(Dense(10, activation='softmax'))

# Check the number of trainable variables
print("Model trainable variables:", len(model.trainable_variables))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model trainable variables: 4

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization, Dense, Dropout, Flatten, GlobalAveragePooling2D, GaussianNoise, Input
from tensorflow.keras import regularizers

# Define input shape
IMAGE_SHAPE = (48, 48, 3)  # Example input shape for grayscale images with 3 channels

# Define the input layer explicitly
model = Sequential()
model.add(Input(shape=IMAGE_SHAPE))  # Define the input layer first

# Load VGG16 model as base model without the top layers
base_model = tf.keras.applications.VGG16(input_shape=IMAGE_SHAPE, include_top=False, weights="imagenet")

# Add the base model to your custom model
model.add(base_model)

# Freeze the layers of the base model
for layer in base_model.layers:
    layer.trainable = False

# Add custom layers
model.add(BatchNormalization())
model.add(GaussianNoise(0.01))
model.add(GlobalAveragePooling2D())

model.add(Flatten())
model.add(Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001), bias_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001), bias_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(7, activation="softmax"))

# Print model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)                   │ (None, 1, 1, 512)           │      14,714,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 1, 1, 512)           │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gaussian_noise (GaussianNoise)       │ (None, 1, 1, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 512)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 7)                   │             903 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,883,399 (56.78 MB)
#  Trainable params: 166,919 (652.03 KB)
#  Non-trainable params: 14,716,480 (56.14 MB)

# %%
from collections import Counter

# Count the number of samples per class
counter = Counter(train_dataset.classes)

# Calculate the maximum count to normalize the class weights
max_val = float(max(counter.values()))

# Define class weights based on the class distribution
class_weights = {class_id: round(max_val / num_images, 2) for class_id, num_images in counter.items()}

# Print class weights
print("Class weights:", class_weights)

# Compile model
import tensorflow.keras.backend as K

def f1_score(y_true, y_pred): 
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_val

METRICS = [
    tf.keras.metrics.BinaryAccuracy(name='accuracy'),
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall'),  
    tf.keras.metrics.AUC(name='auc'),
    f1_score,
]

adam = tf.keras.optimizers.Adam(learning_rate=ADAM_LEARNING_RATE, beta_1=0.9, beta_2=0.999, epsilon=1e-08)

model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=METRICS)
# Out:
# Class weights: {0: 1.81, 1: 16.55, 2: 1.76, 3: 1.0, 4: 1.45, 5: 1.49, 6: 2.28}

# %%
# Corrected ModelCheckpoint filepath extension
mcp = ModelCheckpoint('model.keras', save_best_only=True, monitor='val_loss', mode='min', verbose=1)

# ReduceLROnPlateau and EarlyStopping callback
lrd = ReduceLROnPlateau(monitor='val_loss', patience=PATIENCE, verbose=1, factor=0.50, min_lr=1e-10)
es = EarlyStopping(monitor='val_loss', patience=0, verbose=1, restore_best_weights=True)

# Run the model with a maximum of 30 epochs
history = model.fit(
    train_dataset,
    validation_data=test_dataset,
    epochs=30,  # Stop after 30 epochs
    verbose=1,
    callbacks=[lrd, mcp, es],
    class_weight=class_weights  # Add class weights here
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.8059 - auc: 0.5178 - f1_score: 0.1098 - loss: 5.8071 - precision: 0.1597 - recall: 0.0840
# Epoch 1: val_loss improved from inf to 2.47820, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 151s 312ms/step - accuracy: 0.8059 - auc: 0.5179 - f1_score: 0.1099 - loss: 5.8055 - precision: 0.1599 - recall: 0.0841 - val_accuracy: 0.8543 - val_auc: 0.6108 - val_f1_score: 0.0776 - val_loss: 2.4782 - val_precision: 0.4055 - val_recall: 0.0430 - learning_rate: 1.0000e-04
# Epoch 2/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8190 - auc: 0.5623 - f1_score: 0.1322 - loss: 5.0875 - precision: 0.2103 - recall: 0.0969
# Epoch 2: val_loss improved from 2.47820 to 2.42762, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 56s 124ms/step - accuracy: 0.8190 - auc: 0.5623 - f1_score: 0.1321 - loss: 5.0866 - precision: 0.2103 - recall: 0.0969 - val_accuracy: 0.8528 - val_auc: 0.6444 - val_f1_score: 0.1161 - val_loss: 2.4276 - val_precision: 0.4094 - val_recall: 0.0692 - learning_rate: 1.0000e-04
# Epoch 3/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8254 - auc: 0.5694 - f1_score: 0.1250 - loss: 4.7705 - precision: 0.2205 - recall: 0.0876
# Epoch 3: val_loss improved from 2.42762 to 2.35289, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 55s 122ms/step - accuracy: 0.8254 - auc: 0.5694 - f1_score: 0.1250 - loss: 4.7701 - precision: 0.2205 - recall: 0.0876 - val_accuracy: 0.8543 - val_auc: 0.6647 - val_f1_score: 0.1186 - val_loss: 2.3529 - val_precision: 0.4372 - val_recall: 0.0698 - learning_rate: 1.0000e-04
# Epoch 4/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.8318 - auc: 0.5842 - f1_score: 0.1271 - loss: 4.5407 - precision: 0.2465 - recall: 0.0862
# Epoch 4: val_loss improved from 2.35289 to 2.30410, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 55s 122ms/step - accuracy: 0.8318 - auc: 0.5842 - f1_score: 0.1271 - loss: 4.5402 - precision: 0.2465 - recall: 0.0862 - val_accuracy: 0.8552 - val_auc: 0.6782 - val_f1_score: 0.1159 - val_loss: 2.3041 - val_precision: 0.4534 - val_recall: 0.0678 - learning_rate: 1.0000e-04
# Epoch 5/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.8345 - auc: 0.5883 - f1_score: 0.1148 - loss: 4.4558 - precision: 0.2444 - recall: 0.0756
# Epoch 5: val_loss improved from 2.30410 to 2.26570, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 56s 123ms/step - accuracy: 0.8345 - auc: 0.5883 - f1_score: 0.1148 - loss: 4.4548 - precision: 0.2445 - recall: 0.0756 - val_accuracy: 0.8567 - val_auc: 0.6896 - val_f1_score: 0.1172 - val_loss: 2.2657 - val_precision: 0.4878 - val_recall: 0.0670 - learning_rate: 1.0000e-04
# Epoch 6/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8383 - auc: 0.6019 - f1_score: 0.1057 - loss: 4.2500 - precision: 0.2520 - recall: 0.0670
# Epoch 6: val_loss improved from 2.26570 to 2.23943, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 57s 124ms/step - accuracy: 0.8383 - auc: 0.6019 - f1_score: 0.1057 - loss: 4.2494 - precision: 0.2521 - recall: 0.0670 - val_accuracy: 0.8573 - val_auc: 0.6971 - val_f1_score: 0.1171 - val_loss: 2.2394 - val_precision: 0.5037 - val_recall: 0.0666 - learning_rate: 1.0000e-04
# Epoch 7/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8419 - auc: 0.6140 - f1_score: 0.1029 - loss: 4.1148 - precision: 0.2731 - recall: 0.0640
# Epoch 7: val_loss improved from 2.23943 to 2.21271, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 56s 123ms/step - accuracy: 0.8419 - auc: 0.6140 - f1_score: 0.1029 - loss: 4.1145 - precision: 0.2732 - recall: 0.0640 - val_accuracy: 0.8580 - val_auc: 0.7049 - val_f1_score: 0.1144 - val_loss: 2.2127 - val_precision: 0.5250 - val_recall: 0.0644 - learning_rate: 1.0000e-04
# Epoch 8/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8442 - auc: 0.6195 - f1_score: 0.0959 - loss: 4.0212 - precision: 0.2812 - recall: 0.0582
# Epoch 8: val_loss improved from 2.21271 to 2.19243, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 57s 125ms/step - accuracy: 0.8442 - auc: 0.6195 - f1_score: 0.0959 - loss: 4.0208 - precision: 0.2813 - recall: 0.0582 - val_accuracy: 0.8589 - val_auc: 0.7107 - val_f1_score: 0.1134 - val_loss: 2.1924 - val_precision: 0.5547 - val_recall: 0.0628 - learning_rate: 1.0000e-04
# Epoch 9/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.8470 - auc: 0.6292 - f1_score: 0.0946 - loss: 3.9064 - precision: 0.3071 - recall: 0.0566
# Epoch 9: val_loss improved from 2.19243 to 2.18187, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 56s 122ms/step - accuracy: 0.8470 - auc: 0.6292 - f1_score: 0.0945 - loss: 3.9064 - precision: 0.3071 - recall: 0.0565 - val_accuracy: 0.8586 - val_auc: 0.7132 - val_f1_score: 0.1126 - val_loss: 2.1819 - val_precision: 0.5449 - val_recall: 0.0626 - learning_rate: 1.0000e-04
# Epoch 10/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.8482 - auc: 0.6313 - f1_score: 0.0856 - loss: 3.8297 - precision: 0.3079 - recall: 0.0502
# Epoch 10: val_loss improved from 2.18187 to 2.17153, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 55s 120ms/step - accuracy: 0.8482 - auc: 0.6313 - f1_score: 0.0857 - loss: 3.8297 - precision: 0.3080 - recall: 0.0502 - val_accuracy: 0.8590 - val_auc: 0.7153 - val_f1_score: 0.1110 - val_loss: 2.1715 - val_precision: 0.5582 - val_recall: 0.0628 - learning_rate: 1.0000e-04
# Epoch 11/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.8499 - auc: 0.6405 - f1_score: 0.0920 - loss: 3.7638 - precision: 0.3393 - recall: 0.0536
# Epoch 11: val_loss improved from 2.17153 to 2.15143, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 55s 121ms/step - accuracy: 0.8499 - auc: 0.6405 - f1_score: 0.0920 - loss: 3.7638 - precision: 0.3393 - recall: 0.0536 - val_accuracy: 0.8598 - val_auc: 0.7219 - val_f1_score: 0.1132 - val_loss: 2.1514 - val_precision: 0.5854 - val_recall: 0.0626 - learning_rate: 1.0000e-04
# Epoch 12/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.8516 - auc: 0.6436 - f1_score: 0.0909 - loss: 3.7372 - precision: 0.3643 - recall: 0.0524
# Epoch 12: val_loss improved from 2.15143 to 2.13976, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 55s 122ms/step - accuracy: 0.8516 - auc: 0.6436 - f1_score: 0.0909 - loss: 3.7370 - precision: 0.3642 - recall: 0.0523 - val_accuracy: 0.8601 - val_auc: 0.7249 - val_f1_score: 0.1107 - val_loss: 2.1398 - val_precision: 0.6019 - val_recall: 0.0621 - learning_rate: 1.0000e-04
# Epoch 13/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.8521 - auc: 0.6490 - f1_score: 0.0837 - loss: 3.6876 - precision: 0.3645 - recall: 0.0475
# Epoch 13: val_loss improved from 2.13976 to 2.12610, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - accuracy: 0.8521 - auc: 0.6490 - f1_score: 0.0836 - loss: 3.6876 - precision: 0.3645 - recall: 0.0475 - val_accuracy: 0.8607 - val_auc: 0.7290 - val_f1_score: 0.1105 - val_loss: 2.1261 - val_precision: 0.6317 - val_recall: 0.0605 - learning_rate: 1.0000e-04
# Epoch 14/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8536 - auc: 0.6595 - f1_score: 0.0822 - loss: 3.6393 - precision: 0.3930 - recall: 0.0463
# Epoch 14: val_loss improved from 2.12610 to 2.11738, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 56s 124ms/step - accuracy: 0.8535 - auc: 0.6595 - f1_score: 0.0821 - loss: 3.6392 - precision: 0.3929 - recall: 0.0462 - val_accuracy: 0.8602 - val_auc: 0.7306 - val_f1_score: 0.1056 - val_loss: 2.1174 - val_precision: 0.6127 - val_recall: 0.0591 - learning_rate: 1.0000e-04
# Epoch 15/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.8528 - auc: 0.6626 - f1_score: 0.0788 - loss: 3.6260 - precision: 0.3721 - recall: 0.0445
# Epoch 15: val_loss improved from 2.11738 to 2.10998, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 55s 120ms/step - accuracy: 0.8528 - auc: 0.6626 - f1_score: 0.0788 - loss: 3.6258 - precision: 0.3722 - recall: 0.0444 - val_accuracy: 0.8606 - val_auc: 0.7314 - val_f1_score: 0.1087 - val_loss: 2.1100 - val_precision: 0.6237 - val_recall: 0.0607 - learning_rate: 1.0000e-04
# Epoch 16/30
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8535 - auc: 0.6654 - f1_score: 0.0752 - loss: 3.5971 - precision: 0.3851 - recall: 0.0421
# Epoch 16: val_loss improved from 2.10998 to 2.09836, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 56s 123ms/step - accuracy: 0.8535 - auc: 0.6654 - f1_score: 0.0752 - loss: 3.5969 - precision: 0.3852 - recall: 0.0421 - val_accuracy: 0.8606 - val_auc: 0.7345 - val_f1_score: 0.1076 - val_loss: 2.0984 - val_precision: 0.6261 - val_recall: 0.0602 - learning_rate: 1.0000e-04
# Epoch 17/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8546 - auc: 0.6676 - f1_score: 0.0765 - loss: 3.5593 - precision: 0.4115 - recall: 0.0425
# Epoch 17: val_loss improved from 2.09836 to 2.09009, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 57s 124ms/step - accuracy: 0.8546 - auc: 0.6677 - f1_score: 0.0765 - loss: 3.5592 - precision: 0.4115 - recall: 0.0425 - val_accuracy: 0.8607 - val_auc: 0.7359 - val_f1_score: 0.1036 - val_loss: 2.0901 - val_precision: 0.6409 - val_recall: 0.0567 - learning_rate: 1.0000e-04
# Epoch 18/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8547 - auc: 0.6732 - f1_score: 0.0770 - loss: 3.5127 - precision: 0.4181 - recall: 0.0427
# Epoch 18: val_loss improved from 2.09009 to 2.07659, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 56s 123ms/step - accuracy: 0.8547 - auc: 0.6732 - f1_score: 0.0770 - loss: 3.5128 - precision: 0.4181 - recall: 0.0427 - val_accuracy: 0.8610 - val_auc: 0.7398 - val_f1_score: 0.1103 - val_loss: 2.0766 - val_precision: 0.6425 - val_recall: 0.0606 - learning_rate: 1.0000e-04
# Epoch 19/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.8550 - auc: 0.6775 - f1_score: 0.0777 - loss: 3.4711 - precision: 0.4263 - recall: 0.0431
# Epoch 19: val_loss improved from 2.07659 to 2.06690, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 56s 122ms/step - accuracy: 0.8550 - auc: 0.6775 - f1_score: 0.0777 - loss: 3.4712 - precision: 0.4263 - recall: 0.0431 - val_accuracy: 0.8610 - val_auc: 0.7417 - val_f1_score: 0.1076 - val_loss: 2.0669 - val_precision: 0.6466 - val_recall: 0.0599 - learning_rate: 1.0000e-04
# Epoch 20/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.8549 - auc: 0.6795 - f1_score: 0.0723 - loss: 3.4971 - precision: 0.4167 - recall: 0.0398
# Epoch 20: val_loss improved from 2.06690 to 2.06172, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 55s 120ms/step - accuracy: 0.8549 - auc: 0.6795 - f1_score: 0.0723 - loss: 3.4969 - precision: 0.4168 - recall: 0.0399 - val_accuracy: 0.8613 - val_auc: 0.7412 - val_f1_score: 0.1118 - val_loss: 2.0617 - val_precision: 0.6512 - val_recall: 0.0624 - learning_rate: 1.0000e-04
# Epoch 21/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.8551 - auc: 0.6853 - f1_score: 0.0797 - loss: 3.4790 - precision: 0.4313 - recall: 0.0442
# Epoch 21: val_loss improved from 2.06172 to 2.04994, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 56s 122ms/step - accuracy: 0.8551 - auc: 0.6853 - f1_score: 0.0797 - loss: 3.4789 - precision: 0.4314 - recall: 0.0442 - val_accuracy: 0.8612 - val_auc: 0.7439 - val_f1_score: 0.1143 - val_loss: 2.0499 - val_precision: 0.6403 - val_recall: 0.0642 - learning_rate: 1.0000e-04
# Epoch 22/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.8549 - auc: 0.6852 - f1_score: 0.0758 - loss: 3.4591 - precision: 0.4224 - recall: 0.0419
# Epoch 22: val_loss improved from 2.04994 to 2.04439, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 55s 122ms/step - accuracy: 0.8549 - auc: 0.6853 - f1_score: 0.0758 - loss: 3.4588 - precision: 0.4225 - recall: 0.0420 - val_accuracy: 0.8613 - val_auc: 0.7438 - val_f1_score: 0.1155 - val_loss: 2.0444 - val_precision: 0.6458 - val_recall: 0.0648 - learning_rate: 1.0000e-04
# Epoch 23/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.8555 - auc: 0.6873 - f1_score: 0.0799 - loss: 3.4300 - precision: 0.4433 - recall: 0.0443
# Epoch 23: val_loss improved from 2.04439 to 2.03349, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 55s 120ms/step - accuracy: 0.8555 - auc: 0.6873 - f1_score: 0.0799 - loss: 3.4299 - precision: 0.4434 - recall: 0.0443 - val_accuracy: 0.8615 - val_auc: 0.7461 - val_f1_score: 0.1201 - val_loss: 2.0335 - val_precision: 0.6491 - val_recall: 0.0667 - learning_rate: 1.0000e-04
# Epoch 24/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.8568 - auc: 0.6945 - f1_score: 0.0909 - loss: 3.3821 - precision: 0.4866 - recall: 0.0506
# Epoch 24: val_loss improved from 2.03349 to 2.02756, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - accuracy: 0.8567 - auc: 0.6945 - f1_score: 0.0909 - loss: 3.3821 - precision: 0.4865 - recall: 0.0506 - val_accuracy: 0.8618 - val_auc: 0.7459 - val_f1_score: 0.1214 - val_loss: 2.0276 - val_precision: 0.6602 - val_recall: 0.0666 - learning_rate: 1.0000e-04
# Epoch 25/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8559 - auc: 0.6973 - f1_score: 0.0822 - loss: 3.3633 - precision: 0.4552 - recall: 0.0457
# Epoch 25: val_loss improved from 2.02756 to 2.02045, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 83s 132ms/step - accuracy: 0.8559 - auc: 0.6973 - f1_score: 0.0823 - loss: 3.3633 - precision: 0.4552 - recall: 0.0458 - val_accuracy: 0.8620 - val_auc: 0.7464 - val_f1_score: 0.1271 - val_loss: 2.0204 - val_precision: 0.6572 - val_recall: 0.0708 - learning_rate: 1.0000e-04
# Epoch 26/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8560 - auc: 0.6966 - f1_score: 0.0902 - loss: 3.3792 - precision: 0.4634 - recall: 0.0502
# Epoch 26: val_loss improved from 2.02045 to 2.01082, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 129ms/step - accuracy: 0.8560 - auc: 0.6966 - f1_score: 0.0901 - loss: 3.3789 - precision: 0.4634 - recall: 0.0502 - val_accuracy: 0.8620 - val_auc: 0.7489 - val_f1_score: 0.1242 - val_loss: 2.0108 - val_precision: 0.6584 - val_recall: 0.0701 - learning_rate: 1.0000e-04
# Epoch 27/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8559 - auc: 0.6984 - f1_score: 0.0866 - loss: 3.3461 - precision: 0.4576 - recall: 0.0482
# Epoch 27: val_loss improved from 2.01082 to 1.99938, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 60s 132ms/step - accuracy: 0.8559 - auc: 0.6984 - f1_score: 0.0866 - loss: 3.3460 - precision: 0.4577 - recall: 0.0482 - val_accuracy: 0.8620 - val_auc: 0.7516 - val_f1_score: 0.1261 - val_loss: 1.9994 - val_precision: 0.6560 - val_recall: 0.0712 - learning_rate: 1.0000e-04
# Epoch 28/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8561 - auc: 0.7044 - f1_score: 0.0885 - loss: 3.3088 - precision: 0.4665 - recall: 0.0494
# Epoch 28: val_loss improved from 1.99938 to 1.99442, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 60s 133ms/step - accuracy: 0.8561 - auc: 0.7044 - f1_score: 0.0885 - loss: 3.3090 - precision: 0.4665 - recall: 0.0494 - val_accuracy: 0.8619 - val_auc: 0.7512 - val_f1_score: 0.1237 - val_loss: 1.9944 - val_precision: 0.6574 - val_recall: 0.0695 - learning_rate: 1.0000e-04
# Epoch 29/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8561 - auc: 0.7047 - f1_score: 0.0910 - loss: 3.3129 - precision: 0.4655 - recall: 0.0507
# Epoch 29: val_loss improved from 1.99442 to 1.98408, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 60s 132ms/step - accuracy: 0.8561 - auc: 0.7047 - f1_score: 0.0910 - loss: 3.3129 - precision: 0.4655 - recall: 0.0507 - val_accuracy: 0.8621 - val_auc: 0.7537 - val_f1_score: 0.1291 - val_loss: 1.9841 - val_precision: 0.6595 - val_recall: 0.0723 - learning_rate: 1.0000e-04
# Epoch 30/30
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8566 - auc: 0.7096 - f1_score: 0.0913 - loss: 3.2790 - precision: 0.4838 - recall: 0.0507
# Epoch 30: val_loss improved from 1.98408 to 1.98202, saving model to model.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 60s 131ms/step - accuracy: 0.8566 - auc: 0.7096 - f1_score: 0.0913 - loss: 3.2792 - precision: 0.4837 - recall: 0.0507 - val_accuracy: 0.8618 - val_auc: 0.7524 - val_f1_score: 0.1268 - val_loss: 1.9820 - val_precision: 0.6454 - val_recall: 0.0720 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 30.

# %%
#  Som Scores of train & test set

train_evalation = model.evaluate(train_dataset)
test_evaluation = model.evaluate(test_dataset)
# Out:
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 54s 120ms/step - accuracy: 0.8589 - auc: 0.7387 - f1_score: 0.0922 - loss: 2.0199 - precision: 0.5700 - recall: 0.0507
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 63ms/step - accuracy: 0.8620 - auc: 0.7542 - f1_score: 0.1261 - loss: 1.9744 - precision: 0.6573 - recall: 0.0706

# %%
metric_list = ["Loss","Accuracy", "Precision", "Recall", "Auc", "F1_Score"]

df = pd.DataFrame(list(zip(metric_list, 
                           [round(num, 3) for num in train_evalation], 
                           [round(num, 3) for num in test_evaluation])),
                  columns=['Metric Name', 'Train', 'Validate'])

print('\n\nModel Scores\n')

HTML(df.to_html(escape=False))
# Out:
# Model Scores
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Metric Name</th>
#       <th>Train</th>
#       <th>Validate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Loss</td>
#       <td>2.020</td>
#       <td>1.982</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Accuracy</td>
#       <td>0.859</td>
#       <td>0.862</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Precision</td>
#       <td>0.585</td>
#       <td>0.645</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Recall</td>
#       <td>0.051</td>
#       <td>0.072</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Auc</td>
#       <td>0.738</td>
#       <td>0.752</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>F1_Score</td>
#       <td>0.092</td>
#       <td>0.128</td>
#     </tr>
#   </tbody>
# </table>

# %%
import matplotlib.pyplot as plt

# Extract training history
hs = history.history

acc = hs['accuracy']
val_acc = hs['val_accuracy']
loss = hs['loss']
val_loss = hs['val_loss']
auc = hs['auc']
val_auc = hs['val_auc']
precision = hs['precision']
val_precision = hs['val_precision']
f1 = hs['f1_score']
val_f1 = hs['val_f1_score']

# Set style
plt.style.use('Solarize_Light2')

# Define larger figure size
figsize = (10, 6)

# Accuracy Plot
plt.figure(figsize=figsize)
plt.plot(range(1, len(acc) + 1), acc, label="Training Accuracy", color='blue')
plt.plot(range(1, len(val_acc) + 1), val_acc, label="Validation Accuracy", color='red')
plt.title("Model Accuracy Over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Loss Plot
plt.figure(figsize=figsize)
plt.plot(range(1, len(loss) + 1), loss, label="Training Loss", color='blue')
plt.plot(range(1, len(val_loss) + 1), val_loss, label="Validation Loss", color='red')
plt.title("Model Loss Over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
# AUC Plot
plt.figure(figsize=figsize)
plt.plot(range(1, len(auc) + 1), auc, label="Training AUC", color='blue')
plt.plot(range(1, len(val_auc) + 1), val_auc, label="Validation AUC", color='red')
plt.title("Model AUC Over Epochs")
plt.xlabel("Epochs")
plt.ylabel("AUC")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Precision Plot
plt.figure(figsize=figsize)
plt.plot(range(1, len(precision) + 1), precision, label="Training Precision", color='blue')
plt.plot(range(1, len(val_precision) + 1), val_precision, label="Validation Precision", color='red')
plt.title("Model Precision Over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Precision")
plt.legend()
plt.grid(True)
plt.show()

# %%
# F1-Score Plot
plt.figure(figsize=figsize)
plt.plot(range(1, len(f1) + 1), f1, label="Training F1-Score", color='blue')
plt.plot(range(1, len(val_f1) + 1), val_f1, label="Validation F1-Score", color='red')
plt.title("Model F1-Score Over Epochs")
plt.xlabel("Epochs")
plt.ylabel("F1-Score")
plt.legend()
plt.grid(True)
plt.show()

# %%
y_true = test_dataset.classes
y_pred =  model.predict(test_dataset)
y_pred= tf.argmax(y_pred, axis = 1).numpy()

cm = confusion_matrix(y_true = y_true, y_pred = y_pred)
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 62ms/step

# %%
plt.rcParams['figure.figsize'] = (14,7)

plt.style.use('seaborn-darkgrid')
plt.imshow(cm, interpolation='nearest', cmap='Reds')
plt.title('Confusion matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)    

print('Confusion matrix, without normalization\n')   
print(cm)

print("\n\n")
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j],
        horizontalalignment="center",
        color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# <ipython-input-27-a56f347fa47c>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')
# Confusion matrix, without normalization
#
# [[ 65 152  57 251 179 103 151]
#  [  9  18   8  37  19   7  13]
#  [ 81 140  74 272 181  99 177]
#  [100 260 111 466 355 190 292]
#  [ 83 157  72 327 246 129 219]
#  [ 91 165  84 324 257 123 203]
#  [ 68 110  54 220 139  94 146]]

# %%
plt.style.use('seaborn')

cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(12,6))

im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)

ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       xticklabels=classes, yticklabels=classes,
       title = 'Normalized confusion matrix',
       ylabel='True label',
       xlabel='Predicted label')

plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")


fmt = '.2f' 
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], fmt),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")

fig.tight_layout()
plt.show()
# Out:
# <ipython-input-28-e68e0cb2e8fd>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)

# Corrected filename
model.save_weights("model_30_epochs123.weights.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
plt.style.use('grayscale')
plt.grid(visible=None)
img_path='../input/fer2013/test/neutral/PrivateTest_1129340.jpg'
test_image=image.load_img(img_path,target_size= IMAGE_SIZE,color_mode='grayscale')
test_image=image.img_to_array(test_image)
print(test_image.shape)
plt.imshow(test_image)
plt.show()
# Out:
# (48, 48, 1)

# %%
img=image.load_img(img_path,target_size=IMAGE_SIZE)
img = np.expand_dims(img, axis=0)
print(img.shape)
# Out:
# (1, 48, 48, 3)

# %%
result=model.predict(img)
print(result[0])
y_pred=np.argmax(result[0])
print('The person facial emotion is;',classes[y_pred])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 955ms/step
# [0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 1.0000000e+00
#  3.9543868e-28 0.0000000e+00]
# The person facial emotion is; Neutral
